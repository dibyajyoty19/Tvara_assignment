# %% [markdown]
# <a href="https://colab.research.google.com/github/dibyajyoty19/Tvara_assignment/blob/main/Task2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
API_KEY = "_"
URL = "https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent"

def call_gemini(prompt):
  data = {
      "contents": [{ "parts": [{ "text": prompt}]}]
  }
  response = requests.post(URL +"?key" + API_KEY, json=data)
  return response["candidates"][0]["conetents"]["parts"][0]["text"]

prompt = input("Enter prompt: ")
answer = call_gemini(prompt)
print(answer)
